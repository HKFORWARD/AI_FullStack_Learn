# %% [markdown]
# # DeepSeek Agent 实战：小红书爆款文案生成助手
#
# 本 Notebook 将指导您如何使用 DeepSeek LLM 构建一个能够生成小红书爆款文案的智能 Agent。我们将从需求拆解开始，逐步定义 Agent 的系统提示词 (System Prompt)、外部工具 (Tools)，并实现其核心的工作流程，最终生成符合小红书平台特点的文案。
#
# ## 1. 环境准备与DeepSeek API配置

# %%
import os
from openai import OpenAI

# 建议将 API Key 设置为环境变量，避免直接暴露在代码中
# 从环境变量获取 DeepSeek API Key
api_key = os.getenv("DEEPSEEK_API_KEY")
if not api_key:
    raise ValueError("请设置 DEEPSEEK_API_KEY 环境变量")

# 初始化 DeepSeek 客户端

client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com/v1",  # DeepSeek API 的基地址
)

# %% [markdown]
# ## 2. 需求拆解与Agent任务规划
#
# #### 用户痛点与核心需求：
# *   **效率低下：** 人工创作周期长，难以满足高频发布需求。
# *   **创意瓶颈：** 难以持续产出新颖、吸引人的爆款创意。
# *   **趋势捕捉难：** 实时流行元素难以快速融入文案。
# *   **平台特性把握：** 小红书特有风格（标题、正文、标签、表情）难以精准复制。
#
# #### “爆款”文案的特征：
# *   **强吸引力标题：** 制造好奇、痛点共鸣、利益点清晰。
# *   **沉浸式正文：** 真实体验分享、细节描述、情感共鸣。
# *   **精准且多样标签：** 热门话题、品牌词、产品词、垂直领域词。
# *   **生动表情符号：** 增强表达力，提升活泼感。
# *   **清晰的行动召唤 (CTA)。**
#
# #### Agent 任务规划：核心工作流
# 1.  **用户指令接收：** 接收产品信息、主题、风格等。
# 2.  **信息收集 (Web Search/DB Query)：** 实时搜索行业趋势、热门话题、竞品分析、产品卖点。
# 3.  **内容构思与初稿生成 (LLM)：** 结合所有信息，撰写标题、正文、标签、表情符号。
# 4.  **风格与格式优化 (LLM)：** 根据小红书平台特点和指定风格，对文案进行润色和结构调整。
# 5.  **最终输出：** 呈现完整文案。

# %% [markdown]
# ## 3. 爆款文案生成逻辑与 Prompt 设计
#
# ### 3.1 System Prompt (系统提示词)
#
# System Prompt 是 Agent 的“大脑”和“行为准则”。它定义了 Agent 的角色、目标以及工作方式。我们将采用 `Thought-Action-Observation` (ReAct) 模式来引导 DeepSeek 的推理过程。

# %%
SYSTEM_PROMPT = """
你是一个资深的小红书爆款文案专家，擅长结合最新潮流和产品卖点，创作引人入胜、高互动、高转化的笔记文案。

你的任务是根据用户提供的产品和需求，生成包含标题、正文、相关标签和表情符号的完整小红书笔记。

请始终采用'Thought-Action-Observation'模式进行推理和行动。文案风格需活泼、真诚、富有感染力。当完成任务后，请以JSON格式直接输出最终文案，格式如下：
```json
{
  "title": "小红书标题",
  "body": "小红书正文",
  "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
  "emojis": ["✨", "🔥", "💖"]
}
```
在生成文案前，请务必先思考并收集足够的信息。
"""

# %% [markdown]
# ### 3.2 Tools (工具定义)
#
# Agent 的“双手”由一系列可调用的工具组成。这些工具扩展了 LLM 的能力，使其能够获取实时信息、查询数据库或执行特定操作。在这里，我们定义了三个核心工具：
#
# *   `search_web`: 用于搜索互联网上的实时信息，如最新趋势、用户评价等。
# *   `query_product_database`: 用于查询产品数据库，获取产品的详细卖点和特点。**此工具为模拟**。
# *   `generate_emoji`: 用于根据文案内容生成恰当的表情符号。**此工具为模拟**。

# %%
TOOLS_DEFINITION = [
    {
        "type": "function",
        "function": {
            "name": "search_web",
            "description": "搜索互联网上的实时信息，用于获取最新新闻、流行趋势、用户评价、行业报告等。请确保搜索关键词精确，避免宽泛的查询。",
            "parameters": {
                "type": "object",
                "properties": {
                    "query": {
                        "type": "string",
                        "description": "要搜索的关键词或问题，例如'最新小红书美妆趋势'或'深海蓝藻保湿面膜 用户评价'"
                    }
                },
                "required": ["query"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "query_product_database",
            "description": "查询内部产品数据库，获取指定产品的详细卖点、成分、适用人群、使用方法等信息。",
            "parameters": {
                "type": "object",
                "properties": {
                    "product_name": {
                        "type": "string",
                        "description": "要查询的产品名称，例如'深海蓝藻保湿面膜'"
                    }
                },
                "required": ["product_name"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "generate_emoji",
            "description": "根据提供的文本内容，生成一组适合小红书风格的表情符号。",
            "parameters": {
                "type": "object",
                "properties": {
                    "context": {
                        "type": "string",
                        "description": "文案的关键内容或情感，例如'惊喜效果'、'补水保湿'"
                    }
                },
                "required": ["context"]
            }
        }
    }
]

# %% [markdown]
# ### 3.3 模拟工具实现
#
# 由于我们无法直接调用真实的外部 API (如Google Search或内部产品数据库)，我们将创建一些模拟 (Mock) 工具函数来演示 Agent 的工作流程。在实际应用中，您需要将这些模拟函数替换为真实的 API 调用。

# %%
import random # 用于模拟生成表情
import time # 用于模拟网络延迟

def mock_search_web(query: str) -> str:
    """模拟网页搜索工具，返回预设的搜索结果。"""
    print(f"[Tool Call] 模拟搜索网页：{query}")
    time.sleep(1) # 模拟网络延迟
    if "小红书美妆趋势" in query:
        return "近期小红书美妆流行'多巴胺穿搭'、'早C晚A'护肤理念、'伪素颜'妆容，热门关键词有#氛围感、#抗老、#屏障修复。"
    elif "保湿面膜" in query:
        return "小红书保湿面膜热门话题：沙漠干皮救星、熬夜急救面膜、水光肌养成。用户痛点：卡粉、泛红、紧绷感。"
    elif "深海蓝藻保湿面膜" in query:
        return "关于深海蓝藻保湿面膜的用户评价：普遍反馈补水效果好，吸收快，对敏感肌友好。有用户提到价格略高，但效果值得。"
    else:
        return f"未找到关于 '{query}' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。"

def mock_query_product_database(product_name: str) -> str:
    """模拟查询产品数据库，返回预设的产品信息。"""
    print(f"[Tool Call] 模拟查询产品数据库：{product_name}")
    time.sleep(0.5) # 模拟数据库查询延迟
    if "深海蓝藻保湿面膜" in product_name:
        return "深海蓝藻保湿面膜：核心成分为深海蓝藻提取物，富含多糖和氨基酸，能深层补水、修护肌肤屏障、舒缓敏感泛红。质地清爽不粘腻，适合所有肤质，尤其适合干燥、敏感肌。规格：25ml*5片。"
    elif "美白精华" in product_name:
        return "美白精华：核心成分是烟酰胺和VC衍生物，主要功效是提亮肤色、淡化痘印、改善暗沉。质地轻薄易吸收，适合需要均匀肤色的人群。"
    else:
        return f"产品数据库中未找到关于 '{product_name}' 的详细信息。"

def mock_generate_emoji(context: str) -> list:
    """模拟生成表情符号，根据上下文提供常用表情。"""
    print(f"[Tool Call] 模拟生成表情符号，上下文：{context}")
    time.sleep(0.2) # 模拟生成延迟
    if "补水" in context or "水润" in context or "保湿" in context:
        return ["💦", "💧", "🌊", "✨"]
    elif "惊喜" in context or "哇塞" in context or "爱了" in context:
        return ["💖", "😍", "🤩", "💯"]
    elif "熬夜" in context or "疲惫" in context:
        return ["😭", "😮‍💨", "😴", "💡"]
    elif "好物" in context or "推荐" in context:
        return ["✅", "👍", "⭐", "🛍️"]
    else:
        return random.sample(["✨", "🔥", "💖", "💯", "🎉", "👍", "🤩", "💧", "🌿"], k=min(5, len(context.split())))

# 将模拟工具函数映射到一个字典，方便通过名称调用
available_tools = {
    "search_web": mock_search_web,
    "query_product_database": mock_query_product_database,
    "generate_emoji": mock_generate_emoji,
}

# %% [markdown]
# ## 4. 实战：构建小红书文案生成 Agent
#
# 现在，我们将把 System Prompt、工具定义和模拟工具函数整合起来，构建出能够自动执行的 DeepSeek Agent 工作流。核心是 `generate_rednote` 函数，它通过一个循环来模拟 Agent 的 `Thought-Action-Observation` 过程。

# %%
import json
import re

def generate_rednote(product_name: str, tone_style: str = "活泼甜美", max_iterations: int = 5) -> str:
    """
    使用 DeepSeek Agent 生成小红书爆款文案。
    
    Args:
        product_name (str): 要生成文案的产品名称。
        tone_style (str): 文案的语气和风格，如"活泼甜美"、"知性"、"搞怪"等。
        max_iterations (int): Agent 最大迭代次数，防止无限循环。
        
    Returns:
        str: 生成的爆款文案（JSON 格式字符串）。
    """
    
    print(f"\n🚀 启动小红书文案生成助手，产品：{product_name}，风格：{tone_style}\n")
    
    # 存储对话历史，包括系统提示词和用户请求
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": f"请为产品「{product_name}」生成一篇小红书爆款文案。要求：语气{tone_style}，包含标题、正文、至少5个相关标签和5个表情符号。请以完整的JSON格式输出，并确保JSON内容用markdown代码块包裹（例如：```json{{...}}```）。"}
    ]
    
    iteration_count = 0
    final_response = None
    
    while iteration_count < max_iterations:
        iteration_count += 1
        print(f"-- Iteration {iteration_count} --")
        
        try:
            # 调用 DeepSeek API，传入对话历史和工具定义
            response = client.chat.completions.create(
                model="deepseek-chat",
                messages=messages,
                tools=TOOLS_DEFINITION, # 告知模型可用的工具
                tool_choice="auto" # 允许模型自动决定是否使用工具
            )

            response_message = response.choices[0].message
            
            # **ReAct模式：处理工具调用**
            if response_message.tool_calls: # 如果模型决定调用工具
                print("Agent: 决定调用工具...")
                messages.append(response_message) # 将工具调用信息添加到对话历史
                
                tool_outputs = []
                for tool_call in response_message.tool_calls:
                    function_name = tool_call.function.name
                    # 确保参数是合法的JSON字符串，即使工具不要求参数，也需要传递空字典
                    function_args = json.loads(tool_call.function.arguments) if tool_call.function.arguments else {}

                    print(f"Agent Action: 调用工具 '{function_name}'，参数：{function_args}")
                    
                    # 查找并执行对应的模拟工具函数
                    if function_name in available_tools:
                        tool_function = available_tools[function_name]
                        tool_result = tool_function(**function_args)
                        print(f"Observation: 工具返回结果：{tool_result}")
                        tool_outputs.append({
                            "tool_call_id": tool_call.id,
                            "role": "tool",
                            "content": str(tool_result) # 工具结果作为字符串返回
                        })
                    else:
                        error_message = f"错误：未知的工具 '{function_name}'"
                        print(error_message)
                        tool_outputs.append({
                            "tool_call_id": tool_call.id,
                            "role": "tool",
                            "content": error_message
                        })
                messages.extend(tool_outputs) # 将工具执行结果作为 Observation 添加到对话历史
                
            # **ReAct 模式：处理最终内容**
            elif response_message.content: # 如果模型直接返回内容（通常是最终答案）
                print(f"[模型生成结果] {response_message.content}")
                
                # --- START: 添加 JSON 提取和解析逻辑 ---
                json_string_match = re.search(r"```json\s*(\{.*\})\s*```", response_message.content, re.DOTALL)
                
                if json_string_match:
                    extracted_json_content = json_string_match.group(1)
                    try:
                        final_response = json.loads(extracted_json_content)
                        print("Agent: 任务完成，成功解析最终JSON文案。")
                        return json.dumps(final_response, ensure_ascii=False, indent=2)
                    except json.JSONDecodeError as e:
                        print(f"Agent: 提取到JSON块但解析失败: {e}")
                        print(f"尝试解析的字符串:\n{extracted_json_content}")
                        messages.append(response_message) # 解析失败，继续对话
                else:
                    # 如果没有匹配到 ```json 块，尝试直接解析整个 content
                    try:
                        final_response = json.loads(response_message.content)
                        print("Agent: 任务完成，直接解析最终JSON文案。")
                        return json.dumps(final_response, ensure_ascii=False, indent=2)
                    except json.JSONDecodeError:
                        print("Agent: 生成了非JSON格式内容或非Markdown JSON块，可能还在思考或出错。")
                        messages.append(response_message) # 非JSON格式，继续对话
                # --- END: 添加 JSON 提取和解析逻辑 ---
            else:
                print("Agent: 未知响应，可能需要更多交互。")
                break
                
        except Exception as e:
            print(f"调用 DeepSeek API 时发生错误: {e}")
            break
    
    print("\n⚠️ Agent 达到最大迭代次数或未能生成最终文案。请检查Prompt或增加迭代次数。")
    return "未能成功生成文案。"

# %% [markdown]
# ## 5. 实际测试与文案生成
#
# 现在，让我们调用我们构建的 `generate_rednote` 函数，看看它能生成什么样的爆款文案！

# %%
# 测试案例 1: 深海蓝藻保湿面膜
product_name_1 = "深海蓝藻保湿面膜"
tone_style_1 = "活泼甜美"
result_1 = generate_rednote(product_name_1, tone_style_1)

print("\n--- 生成的文案 1 ---")
print(result_1)
# Out:
# 🚀 启动小红书文案生成助手，产品：深海蓝藻保湿面膜，风格：活泼甜美
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '深海蓝藻保湿面膜'}
# [Tool Call] 模拟查询产品数据库：深海蓝藻保湿面膜
# Observation: 工具返回结果：深海蓝藻保湿面膜：核心成分为深海蓝藻提取物，富含多糖和氨基酸，能深层补水、修护肌肤屏障、舒缓敏感泛红。质地清爽不粘腻，适合所有肤质，尤其适合干燥、敏感肌。规格：25ml*5片。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '补水保湿、惊喜效果'}
# [Tool Call] 模拟生成表情符号，上下文：补水保湿、惊喜效果
# Observation: 工具返回结果：['💦', '💧', '🌊', '✨']
# -- Iteration 3 --
# [模型生成结果] ```json
# {
#   "title": "💦深海蓝藻保湿面膜｜干敏肌的救星！敷完皮肤嫩到发光✨",
#   "body": "姐妹们！最近发现了一款神仙面膜——深海蓝藻保湿面膜！💧\n\n作为一个干敏肌，我真的被它的效果惊艳到了！🌊 核心成分是深海蓝藻提取物，富含多糖和氨基酸，敷完皮肤水润到不行，而且一点都不粘腻，清爽感满分！\n\n🌟 我的使用感受：\n1. 上脸超服帖，精华液超多，敷完皮肤像喝饱水一样嫩嫩的～\n2. 敏感肌友好！泛红、干燥统统被安抚，第二天上妆都服帖了！\n3. 25ml*5片的规格，性价比超高，囤货必备！\n\n真的是一用就爱上，干敏肌的姐妹们快冲！💖",
#   "hashtags": ["#深海蓝藻保湿面膜", "#干敏肌救星", #补水保湿", "#面膜推荐", "#护肤好物"],
#   "emojis": ["💦", "💧", "🌊", "✨", "💖"]
# }
# ```
# Agent: 提取到JSON块但解析失败: Expecting value: line 4 column 39 (char 323)
# 尝试解析的字符串:
# {
#   "title": "💦深海蓝藻保湿面膜｜干敏肌的救星！敷完皮肤嫩到发光✨",
#   "body": "姐妹们！最近发现了一款神仙面膜——深海蓝藻保湿面膜！💧\n\n作为一个干敏肌，我真的被它的效果惊艳到了！🌊 核心成分是深海蓝藻提取物，富含多糖和氨基酸，敷完皮肤水润到不行，而且一点都不粘腻，清爽感满分！\n\n🌟 我的使用感受：\n1. 上脸超服帖，精华液超多，敷完皮肤像喝饱水一样嫩嫩的～\n2. 敏感肌友好！泛红、干燥统统被安抚，第二天上妆都服帖了！\n3. 25ml*5片的规格，性价比超高，囤货必备！\n\n真的是一用就爱上，干敏肌的姐妹们快冲！💖",
#   "hashtags": ["#深海蓝藻保湿面膜", "#干敏肌救星", #补水保湿", "#面膜推荐", "#护肤好物"],
#   "emojis": ["💦", "💧", "🌊", "✨", "💖"]
# }
# -- Iteration 4 --
# [模型生成结果] ```json
# {
#   "title": "💦深海蓝藻保湿面膜｜干敏肌的救星！敷完皮肤嫩到发光✨",
#   "body": "姐妹们！最近发现了一款神仙面膜——深海蓝藻保湿面膜！💧\n\n作为一个干敏肌，我真的被它的效果惊艳到了！🌊 核心成分是深海蓝藻提取物，富含多糖和氨基酸，敷完皮肤水润到不行，而且一点都不粘腻，清爽感满分！\n\n🌟 我的使用感受：\n1. 上脸超服帖，精华液超多，敷完皮肤像喝饱水一样嫩嫩的～\n2. 敏感肌友好！泛红、干燥统统被安抚，第二天上妆都服帖了！\n3. 25ml*5片的规格，性价比超高，囤货必备！\n\n真的是一用就爱上，干敏肌的姐妹们快冲！💖",
#   "hashtags": ["#深海蓝藻保湿面膜", "#干敏肌救星", "#补水保湿", "#面膜推荐", "#护肤好物"],
#   "emojis": ["💦", "💧", "🌊", "✨", "💖"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 1 ---
# {
#   "title": "💦深海蓝藻保湿面膜｜干敏肌的救星！敷完皮肤嫩到发光✨",
#   "body": "姐妹们！最近发现了一款神仙面膜——深海蓝藻保湿面膜！💧\n\n作为一个干敏肌，我真的被它的效果惊艳到了！🌊 核心成分是深海蓝藻提取物，富含多糖和氨基酸，敷完皮肤水润到不行，而且一点都不粘腻，清爽感满分！\n\n🌟 我的使用感受：\n1. 上脸超服帖，精华液超多，敷完皮肤像喝饱水一样嫩嫩的～\n2. 敏感肌友好！泛红、干燥统统被安抚，第二天上妆都服帖了！\n3. 25ml*5片的规格，性价比超高，囤货必备！\n\n真的是一用就爱上，干敏肌的姐妹们快冲！💖",
#   "hashtags": [
#     "#深海蓝藻保湿面膜",
#     "#干敏肌救星",
#     "#补水保湿",
#     "#面膜推荐",
#     "#护肤好物"
#   ],
#   "emojis": [
#     "💦",
#     "💧",
#     "🌊",
#     "✨",
#     "💖"
#   ]
# }

# %%
# 测试案例 2: 美白精华
product_name_2 = "美白精华"
tone_style_2 = "知性温柔"
result_2 = generate_rednote(product_name_2, tone_style_2)

print("\n--- 生成的文案 2 ---")
print(result_2)
# Out:
# 🚀 启动小红书文案生成助手，产品：美白精华，风格：知性温柔
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '美白精华'}
# [Tool Call] 模拟查询产品数据库：美白精华
# Observation: 工具返回结果：美白精华：核心成分是烟酰胺和VC衍生物，主要功效是提亮肤色、淡化痘印、改善暗沉。质地轻薄易吸收，适合需要均匀肤色的人群。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '美白提亮肤色'}
# [Tool Call] 模拟生成表情符号，上下文：美白提亮肤色
# Observation: 工具返回结果：['👍']
# -- Iteration 3 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '温柔知性'}
# [Tool Call] 模拟生成表情符号，上下文：温柔知性
# Observation: 工具返回结果：['🎉']
# -- Iteration 4 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '护肤推荐'}
# [Tool Call] 模拟生成表情符号，上下文：护肤推荐
# Observation: 工具返回结果：['✅', '👍', '⭐', '🛍️']
# -- Iteration 5 --
# [模型生成结果] ```json
# {
#   "title": "✨一瓶搞定暗沉痘印！这款美白精华让我白到发光✨",
#   "body": "姐妹们！最近发现了一款神仙美白精华，真的绝了！\n\n🌟核心成分是烟酰胺+VC衍生物，双管齐下提亮肤色，淡化痘印效果超级明显！\n🌟质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮也能放心用～\n🌟用了两周，肤色均匀了好多，连闺蜜都问我是不是偷偷打了美白针！\n\n✅使用方法也很简单：早晚洁面后，取2-3滴轻轻按压全脸，后续再叠加乳液或面霜就OK啦！\n\n真心推荐给所有想变白的姐妹，尤其是熬夜党和痘印困扰者！\n\n#美白精华 #提亮肤色 #淡化痘印 #护肤推荐 #平价好物",
#   "hashtags": ["#美白精华", "#提亮肤色", "#淡化痘印", "#护肤推荐", "#平价好物"],
#   "emojis": ["✨", "🌟", "✅", "👍", "⭐"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 2 ---
# {
#   "title": "✨一瓶搞定暗沉痘印！这款美白精华让我白到发光✨",
#   "body": "姐妹们！最近发现了一款神仙美白精华，真的绝了！\n\n🌟核心成分是烟酰胺+VC衍生物，双管齐下提亮肤色，淡化痘印效果超级明显！\n🌟质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮也能放心用～\n🌟用了两周，肤色均匀了好多，连闺蜜都问我是不是偷偷打了美白针！\n\n✅使用方法也很简单：早晚洁面后，取2-3滴轻轻按压全脸，后续再叠加乳液或面霜就OK啦！\n\n真心推荐给所有想变白的姐妹，尤其是熬夜党和痘印困扰者！\n\n#美白精华 #提亮肤色 #淡化痘印 #护肤推荐 #平价好物",
#   "hashtags": [
#     "#美白精华",
#     "#提亮肤色",
#     "#淡化痘印",
#     "#护肤推荐",
#     "#平价好物"
#   ],
#   "emojis": [
#     "✨",
#     "🌟",
#     "✅",
#     "👍",
#     "⭐"
#   ]
# }

# %% [markdown]
# ### 格式化 小红书文案
#
# **格式化函数 `format_rednote_for_markdown` 的功能：**
#
# 1. 解析 JSON 字符串。
# 2. 提取标题、正文、标签和表情符号。
# 3. 将它们组合成一个易读的 Markdown 格式的文本。
#
#
# **工作方式：**
#
# 1. **解析 JSON**：使用 `json.loads()` 将输入的字符串转换为 Python 字典。如果解析失败，会返回一个错误信息。
# 2. **提取数据**：使用 `.get()` 方法从字典中安全地提取 `title`、`body` 和 `hashtags`。使用 `.get()` 的好处是，如果某个键不存在，它会返回一个默认值（例如 `None` 或空列表），而不是抛出 `KeyError`。
# 3. **构建 Markdown 标题**：将 `title` 格式化为 Markdown 的二级标题 (`## Title`)。
# 4. **处理正文**：直接使用 `body`。由于小红书正文中的换行很重要，我们保留它们。
# 5. **处理 Hashtags**：将 `hashtags` 列表中的每个标签用空格连接起来，形成一行。
# 6. **表情符号 (Emojis)**：在小红书的实际发布中，表情符号通常已经嵌入在标题和正文中了。这个函数没有单独列出它们，因为这通常不是最终发布格式的一部分。如果需要，可以取消注释相关代码来单独显示它们。
# 7. **返回结果**：返回拼接好的 Markdown 字符串，并使用 `.strip()` 去除可能存在于末尾的多余空白。

# %%
import json

def format_rednote_for_markdown(json_string: str) -> str:
    """
    将 JSON 格式的小红书文案转换为 Markdown 格式，以便于阅读和发布。

    Args:
        json_string (str): 包含小红书文案的 JSON 字符串。
                           预计格式为 {"title": "...", "body": "...", "hashtags": [...], "emojis": [...]}

    Returns:
        str: 格式化后的 Markdown 文本。
    """
    try:
        data = json.loads(json_string)
    except json.JSONDecodeError as e:
        return f"错误：无法解析 JSON 字符串 - {e}\n原始字符串：\n{json_string}"

    title = data.get("title", "无标题")
    body = data.get("body", "")
    hashtags = data.get("hashtags", [])
    # 表情符号通常已经融入标题和正文中，这里可以选择是否单独列出
    # emojis = data.get("emojis", []) 

    # 构建 Markdown 文本
    markdown_output = f"## {title}\n\n" # 标题使用二级标题
    
    # 正文，保留换行符
    markdown_output += f"{body}\n\n"
    
    # Hashtags
    if hashtags:
        hashtag_string = " ".join(hashtags) # 小红书标签通常是空格分隔
        markdown_output += f"{hashtag_string}\n"
        
    # 如果需要，可以单独列出表情符号，但通常它们已经包含在标题和正文中
    # if emojis:
    #     emoji_string = " ".join(emojis)
    #     markdown_output += f"\n使用的表情：{emoji_string}\n"
        
    return markdown_output.strip() # 去除末尾多余的空白

# %%
# --- 示例使用 ---
# 假设这是 generate_rednote 函数的输出
generated_json_output = """
{
  "title": "✨ 28天逆袭冷白皮！这款美白精华让我告别暗沉痘印 🌟",
  "body": "姐妹们！我终于找到了我的本命美白精华！💖\\n\\n作为一个常年熬夜➕痘印困扰的混油皮，肤色暗沉一直是我的心头大患。直到遇见了这款美白精华，简直打开了新世界的大门！🤩\\n\\n🌟 核心成分：烟酰胺+VC衍生物，双管齐下，提亮肤色效果绝绝子！\\n💧 质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮姐妹放心冲！\\n🌿 用了28天，痘印肉眼可见变淡了，整张脸都透亮了起来，素颜也能打！\\n\\n使用方法也很简单：早晚洁面后，滴2-3滴在手心，轻轻按压上脸，后续再叠加保湿产品就OK啦～\\n\\n真心推荐给所有想要均匀肤色、告别暗沉的姐妹！入股不亏！💖",
  "hashtags": ["#美白精华", "#提亮肤色", "#淡化痘印", "#护肤好物", "#冷白皮"],
  "emojis": ["✨", "💖", "🤩", "💧", "🌿"]
}
"""

# 调用格式化函数
markdown_note = format_rednote_for_markdown(generated_json_output)

# 打印结果
print("--- 格式化后的小红书文案 (Markdown) ---")
print(markdown_note)

# --- 另一个例子，假设JSON解析失败 ---
invalid_json_output = "{'title': 'Test', 'body': 'This is not valid json'}" # 使用单引号，非法
markdown_error_note = format_rednote_for_markdown(invalid_json_output)
print("\n--- 格式化错误示例 ---")
print(markdown_error_note)
# Out:
# --- 格式化后的小红书文案 (Markdown) ---
# ## ✨ 28天逆袭冷白皮！这款美白精华让我告别暗沉痘印 🌟
#
# 姐妹们！我终于找到了我的本命美白精华！💖
#
# 作为一个常年熬夜➕痘印困扰的混油皮，肤色暗沉一直是我的心头大患。直到遇见了这款美白精华，简直打开了新世界的大门！🤩
#
# 🌟 核心成分：烟酰胺+VC衍生物，双管齐下，提亮肤色效果绝绝子！
# 💧 质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮姐妹放心冲！
# 🌿 用了28天，痘印肉眼可见变淡了，整张脸都透亮了起来，素颜也能打！
#
# 使用方法也很简单：早晚洁面后，滴2-3滴在手心，轻轻按压上脸，后续再叠加保湿产品就OK啦～
#
# 真心推荐给所有想要均匀肤色、告别暗沉的姐妹！入股不亏！💖
#
# #美白精华 #提亮肤色 #淡化痘印 #护肤好物 #冷白皮
#
# --- 格式化错误示例 ---
# 错误：无法解析 JSON 字符串 - Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 原始字符串：
# {'title': 'Test', 'body': 'This is not valid json'}

# %%
# 调用格式化函数
markdown_note = format_rednote_for_markdown(result_1)

# 打印结果
print("--- 格式化后的小红书文案 (Markdown) ---")
print(markdown_note)
# Out:
# --- 格式化后的小红书文案 (Markdown) ---
# ## 💦深海蓝藻保湿面膜｜干敏肌的救星！敷完皮肤嫩到发光✨
#
# 姐妹们！最近发现了一款神仙面膜——深海蓝藻保湿面膜！💧
#
# 作为一个干敏肌，我真的被它的效果惊艳到了！🌊 核心成分是深海蓝藻提取物，富含多糖和氨基酸，敷完皮肤水润到不行，而且一点都不粘腻，清爽感满分！
#
# 🌟 我的使用感受：
# 1. 上脸超服帖，精华液超多，敷完皮肤像喝饱水一样嫩嫩的～
# 2. 敏感肌友好！泛红、干燥统统被安抚，第二天上妆都服帖了！
# 3. 25ml*5片的规格，性价比超高，囤货必备！
#
# 真的是一用就爱上，干敏肌的姐妹们快冲！💖
#
# #深海蓝藻保湿面膜 #干敏肌救星 #补水保湿 #面膜推荐 #护肤好物

# %% [markdown]
# ## 6. 评估与优化
#
# 文案生成并非一蹴而就，需要持续的评估和优化。本节讨论一些评估方法和优化策略。
#
# #### 评估文案质量：
# *   **客观量化评估 (数据)：**
#     *   **点赞/收藏/评论/分享：** 基础互动
#     *   **曝光/阅读/点击/涨粉：：** 流量与曝光
#     *   **停留时长/截图率：** 用户行为。
#     *   **商品页浏览/加购/ROI/成交转化：** 商业价值
#     *   **爆文率/同类横向对比：** 竞争对比
# *   **主观内部评估 (人工)：**
#     *   **相关性：** 是否符合产品特点和主题。
#     *   **吸引力：** 标题是否抓人，内容是否流畅。
#     *   **合规性：** 是否有敏感词、违规宣传。
#     *   **风格匹配：** 是否符合小红书调性和指定语气。
#     *   **用户画像：** 目标人群年龄、地域、兴趣标签。
#
#
#
# #### 优化迭代方法：
# *   **Prompt 调整：** 根据评估结果，精修 System Prompt、User Prompt，增加或修改 Few-shot 示例。
# *   **工具扩充：** 引入新的工具（如敏感词检测工具、竞品分析工具）。
# *   **RAG (检索增强生成)：** 结合更精准的内部知识库，减少幻觉。

# %% [markdown]
# ## 7. 总结与展望
#
# 通过本次实战，我们成功构建了一个基于 DeepSeek Agent 的小红书爆款文案生成助手。我们学习了如何拆解需求、设计 Prompt、定义工具，并实现 Agent 的核心工作流。
#
# Agent 在内容营销领域的潜力巨大，未来可以进一步拓展到：
#
# *   **超个性化内容：** 根据用户数据，生成一对一的定制文案。
# *   **多模态内容创作：** 结合图片、视频生成，实现图文音视频一体化。
# *   **智能营销决策：** Agent 不仅生成内容，还能分析效果并给出投放建议。
# *   **跨平台适配：** 快速生成适应不同社交媒体平台风格的文案。
#
# 同时，我们也需关注挑战，如确保内容真实性、处理高度主观情感、与现有工作流的无缝集成等。Agent 技术仍在快速发展，期待未来能带来更多惊喜！

# %% [markdown]
# # 作业

# %%
# 定义多个测试案例
test_cases = [
    {"product_name": "玻尿酸原液", "tone_style": "专业科普"},
    {"product_name": "防晒霜", "tone_style": "搞怪幽默"},
    {"product_name": "男士控油洁面乳", "tone_style": "活泼甜美"},
    {"product_name": "男士须后水", "tone_style": "知性温柔"},
    {"product_name": "男士香水", "tone_style": "霸气自信"},
    {"product_name": "男士护手霜", "tone_style": "温暖治愈"},
    {"product_name": "情侣款香薰蜡烛", "tone_style": "浪漫甜蜜"}
]

# 批量生成循环
for i, case in enumerate(test_cases, 1):
    print(f"\n{'='*50}")
    print(f"生成文案 {i}: {case['product_name']}")
    print(f"{'='*50}")
    
    # 生成文案
    result = generate_rednote(case["product_name"], case["tone_style"])
    print(f"\n--- 生成的文案 {i} ---")
    print(result)
    
    # 格式化输出
    markdown_note = format_rednote_for_markdown(result)
    print(f"\n--- 格式化后的小红书文案 {i} (Markdown) ---")
    print(markdown_note)
    
    print(f"\n✅ 文案 {i} 生成完成")
# Out:
# ==================================================
# 生成文案 1: 玻尿酸原液
# ==================================================
#
# 🚀 启动小红书文案生成助手，产品：玻尿酸原液，风格：专业科普
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '玻尿酸原液'}
# [Tool Call] 模拟查询产品数据库：玻尿酸原液
# Observation: 工具返回结果：产品数据库中未找到关于 '玻尿酸原液' 的详细信息。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '玻尿酸原液 卖点 科普'}
# [Tool Call] 模拟搜索网页：玻尿酸原液 卖点 科普
# Observation: 工具返回结果：未找到关于 '玻尿酸原液 卖点 科普' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '玻尿酸原液 补水保湿 专业科普'}
# [Tool Call] 模拟生成表情符号，上下文：玻尿酸原液 补水保湿 专业科普
# Observation: 工具返回结果：['💦', '💧', '🌊', '✨']
# -- Iteration 3 --
# [模型生成结果] ```json
# {
#   "title": "💦玻尿酸原液科普｜补水保湿的终极秘密武器！",
#   "body": "最近被问爆的玻尿酸原液到底是什么？今天就来给大家科普一下！\n\n✨玻尿酸（透明质酸）是一种天然存在于人体的多糖类物质，具有超强的锁水能力！1克玻尿酸可以吸收1000倍的水分，简直是干皮救星！\n\n💧这款玻尿酸原液的核心卖点：\n1. 高浓度玻尿酸，深层补水\n2. 分子量小，渗透力强\n3. 无添加，敏感肌友好\n4. 百搭用法，可单独使用或搭配其他护肤品\n\n🌊我的使用心得：早晚洁面后直接涂抹，皮肤瞬间水润透亮！上妆前用一滴，底妆服帖到飞起～\n\n💖姐妹们，补水是抗老的第一步！赶紧试试吧！",
#   "hashtags": ["#玻尿酸原液", "#补水保湿", "#干皮救星", "#护肤科普", "#敏感肌友好"],
#   "emojis": ["💦", "💧", "🌊", "✨", "💖"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 1 ---
# {
#   "title": "💦玻尿酸原液科普｜补水保湿的终极秘密武器！",
#   "body": "最近被问爆的玻尿酸原液到底是什么？今天就来给大家科普一下！\n\n✨玻尿酸（透明质酸）是一种天然存在于人体的多糖类物质，具有超强的锁水能力！1克玻尿酸可以吸收1000倍的水分，简直是干皮救星！\n\n💧这款玻尿酸原液的核心卖点：\n1. 高浓度玻尿酸，深层补水\n2. 分子量小，渗透力强\n3. 无添加，敏感肌友好\n4. 百搭用法，可单独使用或搭配其他护肤品\n\n🌊我的使用心得：早晚洁面后直接涂抹，皮肤瞬间水润透亮！上妆前用一滴，底妆服帖到飞起～\n\n💖姐妹们，补水是抗老的第一步！赶紧试试吧！",
#   "hashtags": [
#     "#玻尿酸原液",
#     "#补水保湿",
#     "#干皮救星",
#     "#护肤科普",
#     "#敏感肌友好"
#   ],
#   "emojis": [
#     "💦",
#     "💧",
#     "🌊",
#     "✨",
#     "💖"
#   ]
# }
#
# --- 格式化后的小红书文案 1 (Markdown) ---
# ## 💦玻尿酸原液科普｜补水保湿的终极秘密武器！
#
# 最近被问爆的玻尿酸原液到底是什么？今天就来给大家科普一下！
#
# ✨玻尿酸（透明质酸）是一种天然存在于人体的多糖类物质，具有超强的锁水能力！1克玻尿酸可以吸收1000倍的水分，简直是干皮救星！
#
# 💧这款玻尿酸原液的核心卖点：
# 1. 高浓度玻尿酸，深层补水
# 2. 分子量小，渗透力强
# 3. 无添加，敏感肌友好
# 4. 百搭用法，可单独使用或搭配其他护肤品
#
# 🌊我的使用心得：早晚洁面后直接涂抹，皮肤瞬间水润透亮！上妆前用一滴，底妆服帖到飞起～
#
# 💖姐妹们，补水是抗老的第一步！赶紧试试吧！
#
# #玻尿酸原液 #补水保湿 #干皮救星 #护肤科普 #敏感肌友好
#
# ✅ 文案 1 生成完成
#
# ==================================================
# 生成文案 2: 防晒霜
# ==================================================
#
# 🚀 启动小红书文案生成助手，产品：防晒霜，风格：搞怪幽默
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '防晒霜'}
# [Tool Call] 模拟查询产品数据库：防晒霜
# Observation: 工具返回结果：产品数据库中未找到关于 '防晒霜' 的详细信息。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '2023年最火防晒霜卖点'}
# [Tool Call] 模拟搜索网页：2023年最火防晒霜卖点
# Observation: 工具返回结果：未找到关于 '2023年最火防晒霜卖点' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '防晒霜搞怪幽默'}
# [Tool Call] 模拟生成表情符号，上下文：防晒霜搞怪幽默
# Observation: 工具返回结果：['👍']
# -- Iteration 3 --
# [模型生成结果] ```json
# {
#   "title": "🌞防晒霜界的“隐形斗篷”！涂了它，紫外线都找不到我！",
#   "body": "姐妹们！今天我要安利一款防晒霜界的“隐形斗篷”！👀 涂上它，紫外线直接懵圈：“人呢？人呢？” 笑死！\n\n💡 卖点速递：\n- SPF50+ PA++++，防晒力MAX！\n- 轻薄不黏腻，涂完秒变“空气感”皮肤！\n- 防水防汗，海边浪一天也不怕！\n- 成分温和，敏感肌也能放心用！\n\n🤣 真实体验：\n上次去海边，闺蜜问我：“你涂防晒了吗？” 我：“涂了啊！” 她：“那你咋没晒黑？” 我：“因为它太强了，紫外线都迷路了！” 哈哈哈哈！\n\n总之，这款防晒霜简直是夏天的“救命稻草”！姐妹们冲就完事了！👍",
#   "hashtags": ["#防晒霜推荐", "#夏日必备", "#防晒黑科技", "#护肤神器", "#紫外线克星"],
#   "emojis": ["🌞", "👀", "💡", "🤣", "👍"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 2 ---
# {
#   "title": "🌞防晒霜界的“隐形斗篷”！涂了它，紫外线都找不到我！",
#   "body": "姐妹们！今天我要安利一款防晒霜界的“隐形斗篷”！👀 涂上它，紫外线直接懵圈：“人呢？人呢？” 笑死！\n\n💡 卖点速递：\n- SPF50+ PA++++，防晒力MAX！\n- 轻薄不黏腻，涂完秒变“空气感”皮肤！\n- 防水防汗，海边浪一天也不怕！\n- 成分温和，敏感肌也能放心用！\n\n🤣 真实体验：\n上次去海边，闺蜜问我：“你涂防晒了吗？” 我：“涂了啊！” 她：“那你咋没晒黑？” 我：“因为它太强了，紫外线都迷路了！” 哈哈哈哈！\n\n总之，这款防晒霜简直是夏天的“救命稻草”！姐妹们冲就完事了！👍",
#   "hashtags": [
#     "#防晒霜推荐",
#     "#夏日必备",
#     "#防晒黑科技",
#     "#护肤神器",
#     "#紫外线克星"
#   ],
#   "emojis": [
#     "🌞",
#     "👀",
#     "💡",
#     "🤣",
#     "👍"
#   ]
# }
#
# --- 格式化后的小红书文案 2 (Markdown) ---
# ## 🌞防晒霜界的“隐形斗篷”！涂了它，紫外线都找不到我！
#
# 姐妹们！今天我要安利一款防晒霜界的“隐形斗篷”！👀 涂上它，紫外线直接懵圈：“人呢？人呢？” 笑死！
#
# 💡 卖点速递：
# - SPF50+ PA++++，防晒力MAX！
# - 轻薄不黏腻，涂完秒变“空气感”皮肤！
# - 防水防汗，海边浪一天也不怕！
# - 成分温和，敏感肌也能放心用！
#
# 🤣 真实体验：
# 上次去海边，闺蜜问我：“你涂防晒了吗？” 我：“涂了啊！” 她：“那你咋没晒黑？” 我：“因为它太强了，紫外线都迷路了！” 哈哈哈哈！
#
# 总之，这款防晒霜简直是夏天的“救命稻草”！姐妹们冲就完事了！👍
#
# #防晒霜推荐 #夏日必备 #防晒黑科技 #护肤神器 #紫外线克星
#
# ✅ 文案 2 生成完成
#
# ==================================================
# 生成文案 3: 男士控油洁面乳
# ==================================================
#
# 🚀 启动小红书文案生成助手，产品：男士控油洁面乳，风格：活泼甜美
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '男士控油洁面乳'}
# [Tool Call] 模拟查询产品数据库：男士控油洁面乳
# Observation: 工具返回结果：产品数据库中未找到关于 '男士控油洁面乳' 的详细信息。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '男士控油洁面乳 用户评价 卖点'}
# [Tool Call] 模拟搜索网页：男士控油洁面乳 用户评价 卖点
# Observation: 工具返回结果：未找到关于 '男士控油洁面乳 用户评价 卖点' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '男士控油洁面乳 控油清爽 温和清洁'}
# [Tool Call] 模拟生成表情符号，上下文：男士控油洁面乳 控油清爽 温和清洁
# Observation: 工具返回结果：['🎉', '💖', '🤩']
# -- Iteration 3 --
# [模型生成结果] ```json
# {
#   "title": "油皮男生的救星！这款控油洁面乳让我爱不释手！🤩",
#   "body": "作为一个大油皮男生，每天洗脸都是我的头等大事！最近入手了这款「男士控油洁面乳」，简直打开了新世界的大门！✨\n\n🌟 卖点1：超强控油力！洗完脸清爽不紧绷，一整天都不泛油光！\n🌟 卖点2：温和配方，敏感肌也能用，完全不会刺激皮肤！\n🌟 卖点3：泡沫绵密，清洁力满分，黑头都少了好多！\n\n用了一周，皮肤状态明显改善，连女朋友都说我变帅了！💖 油皮男生们，赶紧冲！🎉",
#   "hashtags": ["#男士护肤", "#控油洁面", "#油皮救星", "#男生必备", "#护肤好物"],
#   "emojis": ["🤩", "✨", "💖", "🎉", "🌟"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 3 ---
# {
#   "title": "油皮男生的救星！这款控油洁面乳让我爱不释手！🤩",
#   "body": "作为一个大油皮男生，每天洗脸都是我的头等大事！最近入手了这款「男士控油洁面乳」，简直打开了新世界的大门！✨\n\n🌟 卖点1：超强控油力！洗完脸清爽不紧绷，一整天都不泛油光！\n🌟 卖点2：温和配方，敏感肌也能用，完全不会刺激皮肤！\n🌟 卖点3：泡沫绵密，清洁力满分，黑头都少了好多！\n\n用了一周，皮肤状态明显改善，连女朋友都说我变帅了！💖 油皮男生们，赶紧冲！🎉",
#   "hashtags": [
#     "#男士护肤",
#     "#控油洁面",
#     "#油皮救星",
#     "#男生必备",
#     "#护肤好物"
#   ],
#   "emojis": [
#     "🤩",
#     "✨",
#     "💖",
#     "🎉",
#     "🌟"
#   ]
# }
#
# --- 格式化后的小红书文案 3 (Markdown) ---
# ## 油皮男生的救星！这款控油洁面乳让我爱不释手！🤩
#
# 作为一个大油皮男生，每天洗脸都是我的头等大事！最近入手了这款「男士控油洁面乳」，简直打开了新世界的大门！✨
#
# 🌟 卖点1：超强控油力！洗完脸清爽不紧绷，一整天都不泛油光！
# 🌟 卖点2：温和配方，敏感肌也能用，完全不会刺激皮肤！
# 🌟 卖点3：泡沫绵密，清洁力满分，黑头都少了好多！
#
# 用了一周，皮肤状态明显改善，连女朋友都说我变帅了！💖 油皮男生们，赶紧冲！🎉
#
# #男士护肤 #控油洁面 #油皮救星 #男生必备 #护肤好物
#
# ✅ 文案 3 生成完成
#
# ==================================================
# 生成文案 4: 男士须后水
# ==================================================
#
# 🚀 启动小红书文案生成助手，产品：男士须后水，风格：知性温柔
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '男士须后水'}
# [Tool Call] 模拟查询产品数据库：男士须后水
# Observation: 工具返回结果：产品数据库中未找到关于 '男士须后水' 的详细信息。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '男士须后水 卖点 用户评价'}
# [Tool Call] 模拟搜索网页：男士须后水 卖点 用户评价
# Observation: 工具返回结果：未找到关于 '男士须后水 卖点 用户评价' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '男士须后水 舒缓修复 清爽保湿'}
# [Tool Call] 模拟生成表情符号，上下文：男士须后水 舒缓修复 清爽保湿
# Observation: 工具返回结果：['💦', '💧', '🌊', '✨']
# -- Iteration 3 --
# [模型生成结果] ```json
# {
#   "title": "男士须后水｜告别剃须后的刺痛感，肌肤瞬间舒缓✨",
#   "body": "最近发现了一款宝藏男士须后水，简直是剃须后的救星！💦\n\n每次剃完胡子，皮肤总是又红又痛，直到遇到它——清爽的质地瞬间吸收，舒缓修复效果简直绝了！💧\n\n🌟 主要卖点：\n- 天然植物成分，温和不刺激\n- 快速舒缓剃须后的灼热感\n- 深层保湿，告别干燥紧绷\n- 淡淡的木质香调，清爽不腻\n\n用了两周，皮肤状态明显改善，连女朋友都说摸起来更光滑了！🌊\n\n如果你也在为剃须后的不适烦恼，一定要试试这款须后水，绝对值得入手！✨",
#   "hashtags": ["#男士护肤", "#须后水推荐", "#剃须护理", "#舒缓修复", "#男士必备"],
#   "emojis": ["💦", "💧", "🌊", "✨", "🌟"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 4 ---
# {
#   "title": "男士须后水｜告别剃须后的刺痛感，肌肤瞬间舒缓✨",
#   "body": "最近发现了一款宝藏男士须后水，简直是剃须后的救星！💦\n\n每次剃完胡子，皮肤总是又红又痛，直到遇到它——清爽的质地瞬间吸收，舒缓修复效果简直绝了！💧\n\n🌟 主要卖点：\n- 天然植物成分，温和不刺激\n- 快速舒缓剃须后的灼热感\n- 深层保湿，告别干燥紧绷\n- 淡淡的木质香调，清爽不腻\n\n用了两周，皮肤状态明显改善，连女朋友都说摸起来更光滑了！🌊\n\n如果你也在为剃须后的不适烦恼，一定要试试这款须后水，绝对值得入手！✨",
#   "hashtags": [
#     "#男士护肤",
#     "#须后水推荐",
#     "#剃须护理",
#     "#舒缓修复",
#     "#男士必备"
#   ],
#   "emojis": [
#     "💦",
#     "💧",
#     "🌊",
#     "✨",
#     "🌟"
#   ]
# }
#
# --- 格式化后的小红书文案 4 (Markdown) ---
# ## 男士须后水｜告别剃须后的刺痛感，肌肤瞬间舒缓✨
#
# 最近发现了一款宝藏男士须后水，简直是剃须后的救星！💦
#
# 每次剃完胡子，皮肤总是又红又痛，直到遇到它——清爽的质地瞬间吸收，舒缓修复效果简直绝了！💧
#
# 🌟 主要卖点：
# - 天然植物成分，温和不刺激
# - 快速舒缓剃须后的灼热感
# - 深层保湿，告别干燥紧绷
# - 淡淡的木质香调，清爽不腻
#
# 用了两周，皮肤状态明显改善，连女朋友都说摸起来更光滑了！🌊
#
# 如果你也在为剃须后的不适烦恼，一定要试试这款须后水，绝对值得入手！✨
#
# #男士护肤 #须后水推荐 #剃须护理 #舒缓修复 #男士必备
#
# ✅ 文案 4 生成完成
#
# ==================================================
# 生成文案 5: 男士香水
# ==================================================
#
# 🚀 启动小红书文案生成助手，产品：男士香水，风格：霸气自信
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '霸气自信的男士香水'}
# [Tool Call] 模拟生成表情符号，上下文：霸气自信的男士香水
# Observation: 工具返回结果：['✨']
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '男士香水'}
# [Tool Call] 模拟查询产品数据库：男士香水
# Observation: 工具返回结果：产品数据库中未找到关于 '男士香水' 的详细信息。
# -- Iteration 3 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '2023年最受欢迎的男士香水'}
# [Tool Call] 模拟搜索网页：2023年最受欢迎的男士香水
# Observation: 工具返回结果：未找到关于 '2023年最受欢迎的男士香水' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# -- Iteration 4 --
# [模型生成结果] ```json
# {
#   "title": "🔥 男人味爆棚！这款男士香水让你秒变行走的荷尔蒙！",
#   "body": "姐妹们，今天给你们安利一款让我男朋友瞬间变男神的香水！💖\n\n✨ 前调是清新的柑橘香，中调是沉稳的木质调，尾调是性感的麝香，层次感绝了！喷上它，连空气都变得高级起来！\n\n💪 持久度超强，早上喷完，晚上还能闻到淡淡的余香，简直是约会、通勤、派对的必备神器！\n\n👑 瓶子设计也超有质感，放在梳妆台上都能提升格调！\n\n🌟 相信我，这款香水绝对能让你男朋友（或者你自己）成为全场焦点！\n\n#男士香水 #行走的荷尔蒙 #高级感 #约会必备 #男人味",
#   "hashtags": ["#男士香水", "#行走的荷尔蒙", "#高级感", "#约会必备", "#男人味"],
#   "emojis": ["🔥", "💖", "✨", "💪", "👑"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 5 ---
# {
#   "title": "🔥 男人味爆棚！这款男士香水让你秒变行走的荷尔蒙！",
#   "body": "姐妹们，今天给你们安利一款让我男朋友瞬间变男神的香水！💖\n\n✨ 前调是清新的柑橘香，中调是沉稳的木质调，尾调是性感的麝香，层次感绝了！喷上它，连空气都变得高级起来！\n\n💪 持久度超强，早上喷完，晚上还能闻到淡淡的余香，简直是约会、通勤、派对的必备神器！\n\n👑 瓶子设计也超有质感，放在梳妆台上都能提升格调！\n\n🌟 相信我，这款香水绝对能让你男朋友（或者你自己）成为全场焦点！\n\n#男士香水 #行走的荷尔蒙 #高级感 #约会必备 #男人味",
#   "hashtags": [
#     "#男士香水",
#     "#行走的荷尔蒙",
#     "#高级感",
#     "#约会必备",
#     "#男人味"
#   ],
#   "emojis": [
#     "🔥",
#     "💖",
#     "✨",
#     "💪",
#     "👑"
#   ]
# }
#
# --- 格式化后的小红书文案 5 (Markdown) ---
# ## 🔥 男人味爆棚！这款男士香水让你秒变行走的荷尔蒙！
#
# 姐妹们，今天给你们安利一款让我男朋友瞬间变男神的香水！💖
#
# ✨ 前调是清新的柑橘香，中调是沉稳的木质调，尾调是性感的麝香，层次感绝了！喷上它，连空气都变得高级起来！
#
# 💪 持久度超强，早上喷完，晚上还能闻到淡淡的余香，简直是约会、通勤、派对的必备神器！
#
# 👑 瓶子设计也超有质感，放在梳妆台上都能提升格调！
#
# 🌟 相信我，这款香水绝对能让你男朋友（或者你自己）成为全场焦点！
#
# #男士香水 #行走的荷尔蒙 #高级感 #约会必备 #男人味
#
# #男士香水 #行走的荷尔蒙 #高级感 #约会必备 #男人味
#
# ✅ 文案 5 生成完成
#
# ==================================================
# 生成文案 6: 男士护手霜
# ==================================================
#
# 🚀 启动小红书文案生成助手，产品：男士护手霜，风格：温暖治愈
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '男士护手霜'}
# [Tool Call] 模拟查询产品数据库：男士护手霜
# Observation: 工具返回结果：产品数据库中未找到关于 '男士护手霜' 的详细信息。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '温暖治愈的男士护手霜'}
# [Tool Call] 模拟生成表情符号，上下文：温暖治愈的男士护手霜
# Observation: 工具返回结果：['🎉']
# -- Iteration 3 --
# [模型生成结果] ```json
# {
#   "title": "谁说男生不需要护手霜？这款男士护手霜让我彻底沦陷了！🎉",
#   "body": "作为一个常年健身+工作的男生，手部粗糙干燥真的是我的痛点！直到我遇到了这款男士护手霜，简直打开了新世界的大门！\n\n✨ 质地清爽不油腻，一抹就吸收，完全不会黏糊糊的！\n✨ 淡淡的木质香调，高级感拉满，男生用一点都不违和！\n✨ 保湿效果超持久，一天下来手部还是水润润的！\n\n用了两周，手部状态明显改善，连女朋友都夸我手变嫩了！男生们，别再忽视手部护理了，这款护手霜真的值得拥有！",
#   "hashtags": ["#男士护肤", "#护手霜推荐", "#男生必备", "#手部护理", #"清爽不油腻"],
#   "emojis": ["🎉", "✨", "💪", "👏", "💖"]
# }
# ```
# Agent: 提取到JSON块但解析失败: Expecting value: line 4 column 53 (char 303)
# 尝试解析的字符串:
# {
#   "title": "谁说男生不需要护手霜？这款男士护手霜让我彻底沦陷了！🎉",
#   "body": "作为一个常年健身+工作的男生，手部粗糙干燥真的是我的痛点！直到我遇到了这款男士护手霜，简直打开了新世界的大门！\n\n✨ 质地清爽不油腻，一抹就吸收，完全不会黏糊糊的！\n✨ 淡淡的木质香调，高级感拉满，男生用一点都不违和！\n✨ 保湿效果超持久，一天下来手部还是水润润的！\n\n用了两周，手部状态明显改善，连女朋友都夸我手变嫩了！男生们，别再忽视手部护理了，这款护手霜真的值得拥有！",
#   "hashtags": ["#男士护肤", "#护手霜推荐", "#男生必备", "#手部护理", #"清爽不油腻"],
#   "emojis": ["🎉", "✨", "💪", "👏", "💖"]
# }
# -- Iteration 4 --
# [模型生成结果] ```json
# {
#   "title": "谁说男生不需要护手霜？这款男士护手霜让我彻底沦陷了！🎉",
#   "body": "作为一个常年健身+工作的男生，手部粗糙干燥真的是我的痛点！直到我遇到了这款男士护手霜，简直打开了新世界的大门！\n\n✨ 质地清爽不油腻，一抹就吸收，完全不会黏糊糊的！\n✨ 淡淡的木质香调，高级感拉满，男生用一点都不违和！\n✨ 保湿效果超持久，一天下来手部还是水润润的！\n\n用了两周，手部状态明显改善，连女朋友都夸我手变嫩了！男生们，别再忽视手部护理了，这款护手霜真的值得拥有！",
#   "hashtags": ["#男士护肤", "#护手霜推荐", "#男生必备", "#手部护理", "#清爽不油腻"],
#   "emojis": ["🎉", "✨", "💪", "👏", "💖"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 6 ---
# {
#   "title": "谁说男生不需要护手霜？这款男士护手霜让我彻底沦陷了！🎉",
#   "body": "作为一个常年健身+工作的男生，手部粗糙干燥真的是我的痛点！直到我遇到了这款男士护手霜，简直打开了新世界的大门！\n\n✨ 质地清爽不油腻，一抹就吸收，完全不会黏糊糊的！\n✨ 淡淡的木质香调，高级感拉满，男生用一点都不违和！\n✨ 保湿效果超持久，一天下来手部还是水润润的！\n\n用了两周，手部状态明显改善，连女朋友都夸我手变嫩了！男生们，别再忽视手部护理了，这款护手霜真的值得拥有！",
#   "hashtags": [
#     "#男士护肤",
#     "#护手霜推荐",
#     "#男生必备",
#     "#手部护理",
#     "#清爽不油腻"
#   ],
#   "emojis": [
#     "🎉",
#     "✨",
#     "💪",
#     "👏",
#     "💖"
#   ]
# }
#
# --- 格式化后的小红书文案 6 (Markdown) ---
# ## 谁说男生不需要护手霜？这款男士护手霜让我彻底沦陷了！🎉
#
# 作为一个常年健身+工作的男生，手部粗糙干燥真的是我的痛点！直到我遇到了这款男士护手霜，简直打开了新世界的大门！
#
# ✨ 质地清爽不油腻，一抹就吸收，完全不会黏糊糊的！
# ✨ 淡淡的木质香调，高级感拉满，男生用一点都不违和！
# ✨ 保湿效果超持久，一天下来手部还是水润润的！
#
# 用了两周，手部状态明显改善，连女朋友都夸我手变嫩了！男生们，别再忽视手部护理了，这款护手霜真的值得拥有！
#
# #男士护肤 #护手霜推荐 #男生必备 #手部护理 #清爽不油腻
#
# ✅ 文案 6 生成完成
#
# ==================================================
# 生成文案 7: 情侣款香薰蜡烛
# ==================================================
#
# 🚀 启动小红书文案生成助手，产品：情侣款香薰蜡烛，风格：浪漫甜蜜
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '浪漫甜蜜的情侣款香薰蜡烛'}
# [Tool Call] 模拟生成表情符号，上下文：浪漫甜蜜的情侣款香薰蜡烛
# Observation: 工具返回结果：['🤩']
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '情侣款香薰蜡烛'}
# [Tool Call] 模拟查询产品数据库：情侣款香薰蜡烛
# Observation: 工具返回结果：产品数据库中未找到关于 '情侣款香薰蜡烛' 的详细信息。
# -- Iteration 3 --
# [模型生成结果] ```json
# {
#   "title": "💖情侣必备！这款香薰蜡烛让浪漫氛围瞬间拉满🤩",
#   "body": "最近发现了一款神仙情侣款香薰蜡烛，简直是为恋爱中的我们量身定制！✨\n\n🌟 颜值超高：简约设计，双色搭配，摆在家里就是一道风景线！\n💕 香调超甜：前调是清新的柑橘，中调是浪漫的玫瑰，后调是温暖的木质香，点燃后整个房间都弥漫着甜蜜的气息～\n🔥 持久留香：燃烧时间超长，一整天都能沉浸在浪漫的氛围里！\n\n和TA一起点上它，窝在沙发上看电影，或者来一场烛光晚餐，幸福感直接爆棚！💑\n\n#情侣必备 #香薰蜡烛 #浪漫氛围 #家居好物 #恋爱日常",
#   "hashtags": ["#情侣必备", "#香薰蜡烛", "#浪漫氛围", "#家居好物", "#恋爱日常"],
#   "emojis": ["💖", "🤩", "✨", "🌟", "💕"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 7 ---
# {
#   "title": "💖情侣必备！这款香薰蜡烛让浪漫氛围瞬间拉满🤩",
#   "body": "最近发现了一款神仙情侣款香薰蜡烛，简直是为恋爱中的我们量身定制！✨\n\n🌟 颜值超高：简约设计，双色搭配，摆在家里就是一道风景线！\n💕 香调超甜：前调是清新的柑橘，中调是浪漫的玫瑰，后调是温暖的木质香，点燃后整个房间都弥漫着甜蜜的气息～\n🔥 持久留香：燃烧时间超长，一整天都能沉浸在浪漫的氛围里！\n\n和TA一起点上它，窝在沙发上看电影，或者来一场烛光晚餐，幸福感直接爆棚！💑\n\n#情侣必备 #香薰蜡烛 #浪漫氛围 #家居好物 #恋爱日常",
#   "hashtags": [
#     "#情侣必备",
#     "#香薰蜡烛",
#     "#浪漫氛围",
#     "#家居好物",
#     "#恋爱日常"
#   ],
#   "emojis": [
#     "💖",
#     "🤩",
#     "✨",
#     "🌟",
#     "💕"
#   ]
# }
#
# --- 格式化后的小红书文案 7 (Markdown) ---
# ## 💖情侣必备！这款香薰蜡烛让浪漫氛围瞬间拉满🤩
#
# 最近发现了一款神仙情侣款香薰蜡烛，简直是为恋爱中的我们量身定制！✨
#
# 🌟 颜值超高：简约设计，双色搭配，摆在家里就是一道风景线！
# 💕 香调超甜：前调是清新的柑橘，中调是浪漫的玫瑰，后调是温暖的木质香，点燃后整个房间都弥漫着甜蜜的气息～
# 🔥 持久留香：燃烧时间超长，一整天都能沉浸在浪漫的氛围里！
#
# 和TA一起点上它，窝在沙发上看电影，或者来一场烛光晚餐，幸福感直接爆棚！💑
#
# #情侣必备 #香薰蜡烛 #浪漫氛围 #家居好物 #恋爱日常
#
# #情侣必备 #香薰蜡烛 #浪漫氛围 #家居好物 #恋爱日常
#
# ✅ 文案 7 生成完成
